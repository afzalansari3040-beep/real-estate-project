# %%
import numpy as np
import pandas as pd

# %%
flats=pd.read_csv("C:\\Users\LENOVO\\OneDrive\\Desktop\\Machine learning project\\flats_cleaned.xls")
houses=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Machine learning project\\house_cleaned.xls")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21272\4055256341.py:1: SyntaxWarning: invalid escape sequence '\L'
#   flats=pd.read_csv("C:\\Users\LENOVO\\OneDrive\\Desktop\\Machine learning project\\flats_cleaned.xls")

# %%
flats.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
houses.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft                   area  \
# 0  bptp visionnaire   5.25         20115.0  (242 sq.m.) Plot Area
# 1       independent   5.70        105751.0   (50 sq.m.) Plot Area
# 2       independent   2.10         38251.0   (51 sq.m.) Plot Area
# 3       independent   5.00         43066.0  (108 sq.m.) Plot Area
# 4       independent   3.00         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+  not available
# ...

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.sample(5)
# Out:
#                                       property_name property_type  \
# 977                 3 BHK Flat in Sector 83 Gurgaon          flat
# 2750                3 BHK Flat in Sector 85 Gurgaon          flat
# 612                3 BHK Flat in Sector 37C Gurgaon          flat
# 3587  3 Bedroom House for sale in Sector 40 Gurgaon         house
# 923                2 BHK Flat in Sector 106 Gurgaon          flat
#
#                      society  price  price_per_sqft                  area  \
# 977   vatika lifestyle homes   1.25          6839.0                1828.0
# 2750              godrej air   2.60         12212.0                2129.0
# 612       imperia the esfera   0.99          5500.0                1800.0
# 3587             independent   2.15         23889.0  (84 sq.m.) Plot Area
# 923               paras dews   0.97          8818.0                1100.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
#shuffling
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0              3 BHK Flat in Sector 79 Gurgaon          flat
# 1             4 BHK Flat in Sector 112 Gurgaon          flat
# 2                          3 BHK Flat in Sohna          flat
# 3  4 Bedroom House for sale in Nirvana Country         house
# 4              3 BHK Flat in Sector 69 Gurgaon          flat
#
#                  society  price  price_per_sqft                   area  \
# 0     mapsko mount ville   1.30          8024.0                 1620.0
# 1    experion windchants   5.20         10726.0                 4848.0
# 2  signature global park   0.95          7846.0                 1211.0
# 3    nirvana cedar crest   3.99          8866.0  (418 sq.m.) Plot Area
# 4           tulip violet   1.40          8861.0                 1580.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1620(150.5 sq.m.)Carpet ar...        3         3
# ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv('gurgaon_properties.csv',index=False)
